# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./marziani.csv")
df
# Out:
#      specie colore  n_arti  peso  altezza  larghezza
# 0     Robby  viola    20.0  3.87    14.77      73.22
# 1     Robby  viola    27.0  3.15    28.19      88.44
# 2     Robby  viola    25.0  4.35    12.05      76.74
# 3     Robby    blu    20.0  3.76     9.90      81.37
# 4     Robby    blu    28.0  2.86    19.87      84.65
# ...     ...    ...     ...   ...      ...        ...
# 1995  Simmy  viola    29.0  4.55    35.48      68.47
# 1996  Simmy    blu    23.0  3.84    29.86      71.51
# 1997  Simmy  viola    22.0  4.55    29.41      68.38
# 1998  Simmy  rosso    27.0  4.53    33.12      68.10
# 1999  Simmy  viola    23.0  5.10    18.88      64.95
#
# [2000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1979 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   specie     1979 non-null   object
#  1   colore     1979 non-null   object
#  2   n_arti     1979 non-null   float64
#  3   peso       1979 non-null   float64
#  4   altezza    1979 non-null   float64
#  5   larghezza  1979 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 108.2+ KB

# %%
df_not_NaN = df.dropna()

if df.size != df_not_NaN.size :
    print("Valori NaN trovati")
    df.dropna(inplace = True)
else:
    print("Valori NaN non trovati")
# Out:
# Valori NaN non trovati

# %%
specie = df["specie"].values
colore = df["colore"].values
n_arti = df["n_arti"].values
peso = df["peso"].values
altezza = df["altezza"].values
larghezza = df["larghezza"].values

arr_marz = [specie, colore, n_arti, peso, altezza, larghezza]

# %%
fig, axs = plt.subplots(nrows = 5, ncols = 5, figsize = (25, 25))

for a in range(0, len(arr_marz)-1):
    for b in range(0, len(arr_marz)-1):
        if a == b:
            axs[a, b].hist(arr_marz[b][(specie == "Robby")])
            axs[a, b].hist(arr_marz[b][(specie == "Simmy")], alpha = 0.9)
            axs[a, b].set_title(f"{df.columns[a]} - {df.columns[b]}")
        else:
            axs[a, b].scatter(arr_marz[b][(specie == "Robby")], arr_marz[a][(specie == "Robby")])
            axs[a, b].scatter(arr_marz[b][(specie == "Simmy")], arr_marz[a][(specie == "Simmy")])
            axs[a, b].set_title(f"{df.columns[a]} - {df.columns[b]}")

plt.show()
