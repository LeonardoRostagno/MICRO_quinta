# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Esercizio 1
# Nel file `covid-19_gen1.txt` è presente l'RNA di un virus SARS-COV-2. L'RNA è una sequenza in cui si alternano 4 simboli (detti nucleotidi): A, T, C, G.
# L'RNA del  virus SARS-COV-2 contiene 29903 nucleotidi. Leggi il file e crea un array di Numpy contenente i 29903 elementi, uno per ogni nucleotide secondo l'ordine contenuto nel file.
#
# Utilizza Numpy per:
# 1. calcolare la frequenza assoluta di ogni nucleotide;
# 2. calcolare la frequenza assoluta della sequenza A,T,G;
# 4. sapendo che la sequenza A,T,G,T,T,T,G,T,T,T,T,T sta all'inzio del segmento di RNA che codifica la proteina spike, individuare se la proteina spike è presente nell'RNA: in caso affermativo ottenere la posizione iniziale della proteina spike all'interno dell'array. *SUGGERIMENTO*: costruisci la matrice contenente tutte le possibili sequenze di 12 nucleotidi, nella quale ogni riga rappresenta una sequenza consecutiva di 12 nucleotidi.

# %%
file = open("./covid-19_gen1.txt", "r")
stringa = ""

for line in file.readlines():
    stringa += line[: -1]

file.close()

rna = np.array([n for n in stringa])
aligning_seq = np.array([n for n in spike_seq])

# %%
# punto 1
np.count_nonzero(rna == "T") # per ogni lettera
# Out:
# 9594

# %%
# punto 2
rna_0 = rna[: -2]
rna_1 = np.roll(rna, 1)[: -2]
rna_2 = np.roll(rna, 2)[: -2]

np.count_nonzero(np.logical_and(rna_0 == "A", np.logical_and(rna_1 == "T", rna_2 == "G")))
# Out:
# 469

# %%
# punto 3
spike_seq = "ATGTTTGTTTTT"

temp = [(i + j) for i in range(0, len(rna) - 11) for j in range(0, 12)]

seq_12 = rna[temp].reshape((-1, 12))

# %%
np.all(seq_12 == aligning_seq, axis = 1)
# Out:
# array([False, False, False, ..., False, False, False])

# %% [markdown]
# ## Esercizio 2
# Il file `prezzi.cvs` contiene le serie storiche mensili dei prezzi di alcuni generi alimentari dal Settembre 2011 a Dicembre 2016. Caricare all'interno di opportuni array di Numpy soltanto le serie dei prezzi utili a rispondere alle domande seguenti.
#
# 1. Per il periodo Settembre 2011 - Dicembre 2016 calcola il prezzo di una spesa composta da:
#     - 5kg di Farina di frumento
#     - 1 l di Latte fresco
#     - 1 kg di Caffè tostato
#     - 0.5 kg di Parmigiano Reggiano
# 2. Per la spesa del punto 1 calcola se ci sono dei minimi locali nel prezzo e se si quando (anno, mese).
#
# 3. Traccia un grafico che mostri l'andamento del prezzo del Caffè tostato (gr. 1000).
#
# 4. Calcola un array con le variazioni di prezzo mensile per il Caffè tostato (gr. 1000).
#
# 5. Calcola un array con le variazioni di prezzo mensile per il Burro (gr. 1000).
#
# 6. Traccia un grafico a dispersione che mostri la variazione di prezzo mensile per il Caffè tostato (gr. 1000) rispetto a quella del Burro (gr. 1000).

# %%
data = pd.read_csv("./prezzi.csv", sep = ";") # data è un dataframe
data
# Out:
#     anno       mese  Acqua minerale (cl. 900)  Birra nazionale (cl. 100)  \
# 0   2011  Settembre                      2.54                       1.87
# 1   2011    Ottobre                      2.54                       1.87
# 2   2011   Novembre                      2.54                       1.88
# 3   2011   Dicembre                      2.50                       1.88
# 4   2012    Gennaio                      2.50                       1.89
# 5   2012   Febbraio                      2.48                       1.90
# 6   2012      Marzo                      2.49                       1.91
# 7   2012     Aprile                      2.49                       1.90
# 8   2012     Maggio                      2.52                       1.90
# 9   2012     Giugno                      2.52                       1.92
# 10  2012     Luglio                      2.52                       1.92
# 11  2012     Agosto                      2.52                       1.92
# 12  2012  Settembre                      2.52                       1.91
# 13  2012    Ottobre                      2.49                       1.92
# 14  2012   Dicembre                      2.50                       1.88
# 15  2013    Gennaio                      2.50                       1.89
# 16  2013   Febbraio                      2.48                       1.90
# 17  2013      Marzo                      2.49                       1.91
# 18  2013     Aprile                      2.49                       1.90
# 19  2013     Maggio                      2.52                       1.90
# 20  2013     Giugno                      2.52                       1.92
# 21  2013     Luglio                      2.52                       1.92
# 22  2013     Agosto                      2.52                       1.92
# 23  2013  Settembre                      2.52                       1.91
# 24  2013    Ottobre                      2.49                       1.92
# 25  2013   Novembre                      2.50                       1.94
# 26  2013   Dicembre                      2.51                       1.91
# 27  2014    Gennaio                      2.56                       1.98
# 28  2014   Febbraio                      2.55                       1.98
# 29  2014      Marzo                      2.55                       1.99
# 30  2014     Aprile                      2.55                       1.99
# 31  2014     Maggio                      2.54                       1.98
# 32  2014     Giugno                      2.55                       2.00
# 33  2014     Luglio                      2.52                       1.99
# 34  2014     Agosto                      2.52                       2.00
# 35  2015    Gennaio                      2.28                       2.01
# 36  2015   Febbraio                      2.26                       2.00
# 37  2015      Marzo                      2.33                       1.99
# 38  2015     Aprile                      2.35                       1.99
# 39  2015     Maggio                      2.35                       2.02
# 40  2015     Giugno                      2.34                       2.03
# 41  2015     Luglio                      2.40                       2.03
# 42  2015     Agosto                      2.40                       2.02
# 43  2015  Settembre                      2.40                       2.02
# 44  2015    Ottobre                      2.43                       2.04
# 45  2015   Novembre                      2.42                       2.05
# 46  2015   Dicembre                      2.43                       2.03
# 47  2016    Gennaio                      2.43                       2.06
# 48  2016   Febbraio                      2.42                       2.07
# 49  2016      Marzo                      2.42                       2.27
# 50  2016     Aprile                      2.34                       2.10
# 51  2016     Maggio                      2.34                       2.07
# 52  2016     Giugno                      2.33                       2.04
# 53  2016     Luglio                      2.37                       2.05
# 54  2016     Agosto                      2.49                       2.05
# 55  2016  Settembre                      2.37                       2.05
# 56  2016    Ottobre                      2.47                       2.05
# 57  2016   Novembre                      2.49                       2.05
# 58  2016   Dicembre                      2.49                       2.05
#
#     Biscotti frollini (gr. 1000)  Burro (gr. 1000)  Caffè tostato (gr. 1000)  \
# 0                           4.30             10.03                     13.12
# 1                           4.30              9.95                     13.06
# 2                           4.73              9.93                     13.42
# 3                           4.73             10.12                     13.65
# 4                           4.73             10.19                     13.65
# 5                           4.78             10.17                     13.70
# 6                           4.53             10.32                     13.78
# 7                           4.53             10.20                     13.81
# 8                           4.56             10.26                     13.91
# 9                           4.57             10.38                     14.00
# 10                          4.57             10.51                     13.91
# 11                          4.58             10.55                     14.07
# 12                          4.57             10.66                     14.06
# 13                          4.47             10.68                     14.06
# 14                          4.73             10.12                     13.65
# 15                          4.73             10.19                     13.65
# 16                          4.78             10.17                     13.70
# 17                          4.53             10.32                     13.78
# 18                          4.53             10.20                     13.81
# 19                          4.56             10.26                     13.91
# 20                          4.57             10.38                     14.00
# 21                          4.57             10.51                     13.91
# 22                          4.58             10.55                     14.07
# 23                          4.57             10.66                     14.06
# 24                          4.47             10.68                     14.06
# 25                          4.45             10.59                     14.02
# 26                          4.56             10.67                     13.91
# 27                          4.56             10.72                     14.01
# 28                          4.56             11.06                     14.03
# 29                          4.56             11.21                     13.98
# 30                          4.41             11.34                     13.96
# 31                          4.41             11.34                     13.39
# 32                          4.44             11.34                     13.39
# 33                          4.44             11.18                     13.19
# 34                          4.46             11.24                     13.18
# 35                          4.49             10.88                     13.40
# 36                          4.58             10.68                     13.83
# 37                          4.57             10.87                     13.80
# 38                          4.50             10.91                     13.86
# 39                          4.23             10.91                     14.05
# 40                          4.22             10.81                     14.06
# 41                          4.22             10.74                     13.84
# 42                          4.22             10.74                     13.84
# 43                          4.22             10.85                     13.86
# 44                          4.22             10.86                     13.84
# 45                          4.22             11.18                     14.03
# 46                          4.32             10.87                     14.32
# 47                          4.23             10.65                     14.09
# 48                          4.23             10.93                     13.89
# 49                          4.22             10.82                     13.96
# 50                          4.31             10.46                     13.32
# 51                          4.31             10.54                     13.32
# 52                          4.31             10.55                     13.34
# 53                          4.17             10.44                     13.43
# 54                          4.20             10.11                     13.24
# 55                          4.07             10.23                     13.40
# 56                          4.10             10.12                     13.40
# 57                          4.10             10.15                     13.04
# 58                          4.10             10.07                     13.04
#
#     Carne fresca bovino adulto. primo taglio (gr. 1000)  \
# 0                                               16.72
# 1                                               16.72
# 2                                               16.72
# 3                                               16.78
# 4                                               16.83
# 5                                               16.88
# 6                                               16.92
# 7                                               16.96
# 8                                               16.97
# 9                                               16.97
# 10                                              16.97
# 11                                              16.97
# 12                                              16.97
# 13                                              17.02
# 14                                              16.78
# 15                                              16.83
# 16                                              16.88
# 17                                              16.92
# 18                                              16.96
# 19                                              16.97
# 20                                              16.97
# 21                                              16.97
# 22                                              16.97
# 23                                              16.97
# 24                                              17.02
# 25                                              17.10
# 26                                              17.11
# 27                                              17.11
# 28                                              17.11
# 29                                              17.11
# 30                                              17.16
# 31                                              17.21
# 32                                              17.21
# 33                                              17.24
# 34                                              17.26
# 35                                              17.28
# 36                                              17.38
# 37                                              17.39
# 38                                              17.44
# 39                                              17.43
# 40                                              17.44
# 41                                              17.63
# 42                                              17.63
# 43                                              17.66
# 44                                              17.82
# 45                                              17.82
# 46                                              17.82
# 47                                              17.82
# 48                                              17.82
# 49                                              17.76
# 50                                              17.81
# 51                                              17.70
# 52                                              17.70
# 53                                              17.70
# 54                                              17.68
# 55                                              17.75
# 56                                              17.79
# 57                                              17.99
# 58                                              17.86
#
#     Carne fresca suina con osso (gr. 1000)  Farina di frumento (gr. 1000)  \
# 0                                     7.41                           0.81
# 1                                     7.43                           0.82
# 2                                     7.49                           0.81
# 3                                     7.53                           0.80
# 4                                     7.58                           0.80
# 5                                     7.32                           0.81
# 6                                     7.36                           0.82
# 7                                     7.36                           0.81
# 8                                     7.30                           0.81
# 9                                     7.16                           0.82
# 10                                    7.18                           0.81
# 11                                    7.22                           0.80
# 12                                    7.27                           0.81
# 13                                    7.27                           0.81
# 14                                    7.53                           0.80
# 15                                    7.58                           0.80
# 16                                    7.32                           0.81
# 17                                    7.36                           0.82
# 18                                    7.36                           0.81
# 19                                    7.30                           0.81
# 20                                    7.16                           0.82
# 21                                    7.18                           0.81
# 22                                    7.22                           0.80
# 23                                    7.27                           0.81
# 24                                    7.27                           0.81
# 25                                    7.25                           0.82
# 26                                    7.30                           0.82
# 27                                    7.31                           0.82
# 28                                    7.31                           0.82
# 29                                    7.31                           0.82
# 30                                    7.34                           0.83
# 31                                    7.24                           0.83
# 32                                    7.24                           0.83
# 33                                    7.29                           0.83
# 34                                    7.35                           0.83
# 35                                    7.40                           0.87
# 36                                    7.36                           0.83
# 37                                    7.36                           0.83
# 38                                    7.43                           0.83
# 39                                    7.43                           0.80
# 40                                    7.41                           0.80
# 41                                    7.37                           0.80
# 42                                    7.37                           0.78
# 43                                    7.38                           0.78
# 44                                    7.38                           0.78
# 45                                    7.31                           0.79
# 46                                    7.26                           0.79
# 47                                    7.31                           0.75
# 48                                    7.13                           0.79
# 49                                    7.10                           0.78
# 50                                    7.19                           0.75
# 51                                    7.25                           0.75
# 52                                    7.22                           0.75
# 53                                    7.23                           0.75
# 54                                    7.16                           0.73
# 55                                    7.25                           0.76
# 56                                    7.31                           0.76
# 57                                    7.31                           0.75
# 58                                    7.22                           0.75
#
#     ...  Prosciutto cotto (gr. 1000)  Prosciutto crudo (gr. 1000)  \
# 0   ...                        25.13                        28.77
# 1   ...                        25.13                        28.82
# 2   ...                        25.02                        28.90
# 3   ...                        25.02                        28.52
# 4   ...                        25.02                        28.52
# 5   ...                        25.08                        28.73
# 6   ...                        25.08                        28.73
# 7   ...                        25.17                        28.76
# 8   ...                        25.17                        28.92
# 9   ...                        25.17                        28.98
# 10  ...                        25.17                        28.92
# 11  ...                        25.17                        28.92
# 12  ...                        25.17                        29.00
# 13  ...                        25.64                        29.35
# 14  ...                        25.02                        28.52
# 15  ...                        25.02                        28.52
# 16  ...                        25.08                        28.73
# 17  ...                        25.08                        28.73
# 18  ...                        25.17                        28.76
# 19  ...                        25.17                        28.92
# 20  ...                        25.17                        28.98
# 21  ...                        25.17                        28.92
# 22  ...                        25.17                        28.92
# 23  ...                        25.17                        29.00
# 24  ...                        25.64                        29.35
# 25  ...                        25.64                        29.52
# 26  ...                        25.64                        29.67
# 27  ...                        25.64                        29.42
# 28  ...                        25.64                        29.50
# 29  ...                        25.64                        29.53
# 30  ...                        25.64                        29.48
# 31  ...                        25.70                        29.53
# 32  ...                        25.77                        29.63
# 33  ...                        25.87                        29.63
# 34  ...                        25.70                        29.69
# 35  ...                        26.22                        29.84
# 36  ...                        26.22                        29.84
# 37  ...                        26.22                        29.84
# 38  ...                        26.28                        29.84
# 39  ...                        26.28                        29.97
# 40  ...                        26.28                        29.97
# 41  ...                        26.28                        29.97
# 42  ...                        26.28                        30.00
# 43  ...                        26.21                        30.12
# 44  ...                        26.33                        30.12
# 45  ...                        26.30                        30.07
# 46  ...                        26.60                        30.26
# 47  ...                        25.61                        29.81
# 48  ...                        25.78                        29.68
# 49  ...                        25.43                        29.93
# 50  ...                        25.54                        30.03
# 51  ...                        25.54                        30.09
# 52  ...                        25.75                        30.40
# 53  ...                        25.82                        30.27
# 54  ...                        26.37                        30.27
# 55  ...                        26.03                        30.48
# 56  ...                        26.18                        30.51
# 57  ...                        26.20                        30.38
# 58  ...                        26.75                        30.31
#
#     Riso (gr. 1000)  Stracchino o crescenza (gr. 1000)  \
# 0              2.49                              11.54
# 1              2.49                              11.66
# 2              2.49                              11.36
# 3              2.48                              11.15
# 4              2.49                              11.18
# 5              2.50                              11.34
# 6              2.49                              11.34
# 7              2.47                              11.30
# 8              2.48                              11.61
# 9              2.41                              11.49
# 10             2.41                              11.42
# 11             2.42                              11.45
# 12             2.41                              11.35
# 13             2.41                              11.50
# 14             2.48                              11.15
# 15             2.49                              11.18
# 16             2.50                              11.34
# 17             2.49                              11.34
# 18             2.47                              11.30
# 19             2.48                              11.61
# 20             2.41                              11.49
# 21             2.41                              11.42
# 22             2.42                              11.45
# 23             2.41                              11.35
# 24             2.41                              11.50
# 25             2.41                              11.37
# 26             2.49                              11.51
# 27             2.48                              11.51
# 28             2.50                              11.61
# 29             2.49                              11.65
# 30             2.49                              11.70
# 31             2.50                              11.83
# 32             2.50                              11.83
# 33             2.56                              11.62
# 34             2.55                              11.58
# 35             2.61                              10.82
# 36             2.62                              10.86
# 37             2.61                              11.13
# 38             2.62                              10.96
# 39             2.67                              10.94
# 40             2.66                              11.00
# 41             2.67                              11.05
# 42             2.69                              11.09
# 43             2.70                              11.09
# 44             2.71                              11.09
# 45             2.73                              11.06
# 46             2.79                              10.95
# 47             2.75                              11.00
# 48             2.76                              10.95
# 49             2.76                              11.00
# 50             2.73                              10.79
# 51             2.68                              11.01
# 52             2.72                              11.14
# 53             2.72                              10.96
# 54             2.73                              10.67
# 55             2.72                              10.91
# 56             2.72                              10.91
# 57             2.72                              10.91
# 58             2.72                              11.28
#
#     Succo di frutta (cl. 100)  Tonno in olio d'oliva (gr. 1000)  \
# 0                        1.60                             12.73
# 1                        1.60                             12.70
# 2                        1.59                             12.72
# 3                        1.59                             13.03
# 4                        1.59                             13.27
# 5                        1.59                             13.83
# 6                        1.59                             13.97
# 7                        1.60                             14.09
# 8                        1.59                             14.07
# 9                        1.60                             14.28
# 10                       1.59                             14.03
# 11                       1.59                             14.10
# 12                       1.59                             13.93
# 13                       1.59                             13.84
# 14                       1.59                             13.03
# 15                       1.59                             13.27
# 16                       1.59                             13.83
# 17                       1.59                             13.97
# 18                       1.60                             14.09
# 19                       1.59                             14.07
# 20                       1.60                             14.28
# 21                       1.59                             14.03
# 22                       1.59                             14.10
# 23                       1.59                             13.93
# 24                       1.59                             13.84
# 25                       1.56                             13.85
# 26                       1.56                             14.23
# 27                       1.56                             17.98
# 28                       1.56                             17.99
# 29                       1.55                             17.96
# 30                       1.58                             18.05
# 31                       1.59                             18.21
# 32                       1.58                             18.16
# 33                       1.58                             18.25
# 34                       1.57                             18.27
# 35                       1.65                             18.00
# 36                       1.60                             18.51
# 37                       1.60                             19.10
# 38                       1.61                             19.21
# 39                       1.61                             18.67
# 40                       1.61                             18.18
# 41                       1.53                             18.21
# 42                       1.53                             18.20
# 43                       1.53                             18.21
# 44                       1.53                             18.26
# 45                       1.54                             18.30
# 46                       1.54                             18.30
# 47                       1.54                             18.33
# 48                       1.54                             18.26
# 49                       1.54                             18.26
# 50                       1.50                             18.18
# 51                       1.52                             18.09
# 52                       1.51                             18.33
# 53                       1.52                             18.36
# 54                       1.51                             18.33
# 55                       1.53                             18.33
# 56                       1.52                             17.46
# 57                       1.52                             17.49
# 58                       1.51                             17.84
#
#     Uova di gallina (pz. 6)  Vino da tavola (cl. 100)  Yogurt (gr. 125)  \
# 0                      1.59                      3.24              0.56
# 1                      1.58                      3.25              0.56
# 2                      1.57                      3.33              0.55
# 3                      1.57                      3.43              0.55
# 4                      1.56                      3.36              0.55
# 5                      1.56                      3.22              0.55
# 6                      1.58                      3.35              0.56
# 7                      1.64                      3.36              0.55
# 8                      1.64                      3.37              0.56
# 9                      1.64                      3.38              0.56
# 10                     1.65                      3.48              0.57
# 11                     1.66                      3.53              0.57
# 12                     1.66                      3.55              0.56
# 13                     1.67                      3.60              0.56
# 14                     1.57                      3.43              0.55
# 15                     1.56                      3.36              0.55
# 16                     1.56                      3.22              0.55
# 17                     1.58                      3.35              0.56
# 18                     1.64                      3.36              0.55
# 19                     1.64                      3.37              0.56
# 20                     1.64                      3.38              0.56
# 21                     1.65                      3.48              0.57
# 22                     1.66                      3.53              0.57
# 23                     1.66                      3.55              0.56
# 24                     1.67                      3.60              0.56
# 25                     1.63                      3.62              0.56
# 26                     1.63                      3.61              0.55
# 27                     1.63                      3.61              0.57
# 28                     1.64                      3.61              0.56
# 29                     1.65                      3.61              0.56
# 30                     1.65                      3.65              0.56
# 31                     1.65                      3.65              0.57
# 32                     1.65                      3.61              0.57
# 33                     1.64                      3.63              0.56
# 34                     1.64                      3.63              0.56
# 35                     1.65                      3.75              0.57
# 36                     1.65                      3.88              0.57
# 37                     1.65                      3.88              0.56
# 38                     1.64                      3.89              0.56
# 39                     1.64                      3.90              0.56
# 40                     1.66                      3.91              0.56
# 41                     1.66                      3.91              0.56
# 42                     1.68                      3.67              0.56
# 43                     1.66                      3.68              0.56
# 44                     1.66                      3.68              0.56
# 45                     1.65                      3.69              0.56
# 46                     1.65                      3.78              0.56
# 47                     1.26                      3.62              0.56
# 48                     1.26                      3.73              0.56
# 49                     1.25                      3.77              0.56
# 50                     1.27                      3.77              0.54
# 51                     1.27                      3.77              0.55
# 52                     1.24                      3.94              0.54
# 53                     1.21                      3.81              0.54
# 54                     1.21                      3.81              0.53
# 55                     1.22                      3.81              0.54
# 56                     1.21                      3.85              0.54
# 57                     1.22                      3.85              0.54
# 58                     1.22                      3.90              0.54
#
#     Zucchero (gr. 1000)
# 0                  1.16
# 1                  1.16
# 2                  1.16
# 3                  1.16
# 4                  1.16
# 5                  1.16
# 6                  1.15
# 7                  1.15
# 8                  1.15
# 9                  1.15
# 10                 1.14
# 11                 1.14
# 12                 1.13
# 13                 1.13
# 14                 1.16
# 15                 1.16
# 16                 1.16
# 17                 1.15
# 18                 1.15
# 19                 1.15
# 20                 1.15
# 21                 1.14
# 22                 1.14
# 23                 1.13
# 24                 1.13
# 25                 1.13
# 26                 1.13
# 27                 1.13
# 28                 1.13
# 29                 1.11
# 30                 1.12
# 31                 1.12
# 32                 1.10
# 33                 1.10
# 34                 1.10
# 35                 1.09
# 36                 1.10
# 37                 1.09
# 38                 1.09
# 39                 1.08
# 40                 1.07
# 41                 1.08
# 42                 1.08
# 43                 1.08
# 44                 1.08
# 45                 1.08
# 46                 1.08
# 47                 1.06
# 48                 1.08
# 49                 1.07
# 50                 1.04
# 51                 1.08
# 52                 1.07
# 53                 1.08
# 54                 1.03
# 55                 1.09
# 56                 1.09
# 57                 1.09
# 58                 1.09
#
# [59 rows x 32 columns]

# %%
arr_dtanno = data["anno"].values
arr_dtmese = data["mese"].values
arr_farina = data["Farina di frumento (gr. 1000)"].values
arr_latte = data["Latte fresco (cl. 100)"].values
arr_caffe = data["Caffè tostato (gr. 1000)"].values
arr_parmigiano = data["Parmigiano Reggiano (gr. 1000)"].values
arr_burro = data["Burro (gr. 1000)"].values

# %%
# PUNTO 1
spesa = (arr_farina * 5) + (arr_latte * 10) + arr_caffe + (arr_parmigiano / 2)
arr_spesa = np.array(spesa)
arr_spesa
# Out:
# array([44.39 , 44.39 , 43.64 , 43.47 , 43.485, 43.47 , 43.295, 43.225,
#        43.64 , 44.15 , 43.81 , 43.82 , 43.76 , 43.7  , 43.47 , 43.485,
#        43.47 , 43.295, 43.225, 43.64 , 44.15 , 43.81 , 43.82 , 43.76 ,
#        43.7  , 43.81 , 43.7  , 44.64 , 44.38 , 44.57 , 44.71 , 44.37 ,
#        44.275, 44.33 , 44.   , 44.115, 44.345, 44.315, 44.345, 44.385,
#        44.25 , 43.73 , 43.645, 43.665, 43.66 , 43.87 , 44.195, 42.245,
#        42.215, 42.255, 41.39 , 41.29 , 41.32 , 41.31 , 40.745, 41.16 ,
#        41.23 , 40.915, 40.885])

# %%
# PUNTO 2
arr_prec = np.roll(arr_spesa, -1) [1: -1]
arr_succ = np.roll(arr_spesa, 1) [1: -1]
spesa = arr_spesa [1: -1]
arr_anno = arr_dtanno [1: -1]
arr_mese = arr_dtmese [1: -1]

print(arr_anno[np.logical_and(arr_prec > spesa, arr_succ < spesa)])
print(arr_mese[np.logical_and(arr_prec > spesa, arr_succ < spesa)])
# Out:
# [2012 2013 2014 2015 2015 2015 2016]
# ['Maggio' 'Maggio' 'Marzo' 'Gennaio' 'Aprile' 'Novembre' 'Settembre']

# %%
# PUNTO 3
fig, ax = plt.subplots(figsize = (10, 6))
ax.plot(arr_caffe, "y")
ax.set_title("Andamento caffè")
plt.show()

# %%
# PUNTO 4
var_mens_caffe = np.roll(arr_caffe, 1) - arr_caffe
arr_mens_caffe = np.array(var_mens_caffe)
arr_mens_caffe
# Out:
# array([-0.08,  0.06, -0.36, -0.23,  0.  , -0.05, -0.08, -0.03, -0.1 ,
#        -0.09,  0.09, -0.16,  0.01,  0.  ,  0.41,  0.  , -0.05, -0.08,
#        -0.03, -0.1 , -0.09,  0.09, -0.16,  0.01,  0.  ,  0.04,  0.11,
#        -0.1 , -0.02,  0.05,  0.02,  0.57,  0.  ,  0.2 ,  0.01, -0.22,
#        -0.43,  0.03, -0.06, -0.19, -0.01,  0.22,  0.  , -0.02,  0.02,
#        -0.19, -0.29,  0.23,  0.2 , -0.07,  0.64,  0.  , -0.02, -0.09,
#         0.19, -0.16,  0.  ,  0.36,  0.  ])

# %%
# PUNTO 5
var_mens_burro = np.roll(arr_burro, 1) - arr_burro
arr_mens_burro = np.array(var_mens_burro)
arr_mens_burro
# Out:
# array([ 0.04,  0.08,  0.02, -0.19, -0.07,  0.02, -0.15,  0.12, -0.06,
#        -0.12, -0.13, -0.04, -0.11, -0.02,  0.56, -0.07,  0.02, -0.15,
#         0.12, -0.06, -0.12, -0.13, -0.04, -0.11, -0.02,  0.09, -0.08,
#        -0.05, -0.34, -0.15, -0.13,  0.  ,  0.  ,  0.16, -0.06,  0.36,
#         0.2 , -0.19, -0.04,  0.  ,  0.1 ,  0.07,  0.  , -0.11, -0.01,
#        -0.32,  0.31,  0.22, -0.28,  0.11,  0.36, -0.08, -0.01,  0.11,
#         0.33, -0.12,  0.11, -0.03,  0.08])

# %%
# PUNTO 6
fig, ax = plt.subplots(figsize = (20, 10))
ax.scatter(arr_mens_caffe, arr_mens_burro, s = 5.0)
ax.set_title("Correlazione Caffè-Burro")
ax.set_xlabel("Caffè")
ax.set_ylabel("Burro")

plt.show()

# %% [markdown]
# ## Esercizio 3
# L'array `array_punti` è un array di Numpy come quello sottostante, contenente quattro coppie di coordinate spaziali intere scelte a caso, che rappresentano quattro punti nel piano. Essi sono i quattro vertici di una figura geometrica piana, letti in verso anti-orario. Facendo uso di Numpy: [suggerimento: usare funzione unique()]
# 1. crea una funzione che verifichi se la figura geometrica è un quadrilatero, un triangolo, un segmento oppure un punto;
# 2. crea una funzione che calcoli il perimetro della figura.

# %%
array_punti= np.random.randint(0.,5,(4,2))
array_punti
# Out:
# array([[1, 2],
#        [1, 1],
#        [0, 1],
#        [3, 2]])

# %%
# punto 1
def forma(num):
    if num == 1:
        return "punto"
    elif num == 2:
        return "segmento"
    elif num == 3:
        return "Triangolo"
    else:
        return "quadrilatero"

# %%
risultati = len(np.unique(array_punti, axis = 0))
print(f"Questi punti formano un {forma(risultati)}")
# Out:
# Questi punti formano un quadrilatero

# %%
# punto 2
sommone = np.sum((array_punti - np.roll(array_punti, 1, axis = 0)) ** 2, axis = 1)
sommone
# Out:
# array([ 4,  1,  1, 10], dtype=int32)

# %%
np.sum(np.sqrt(sommone))
# Out:
# 7.16227766016838

# %% [markdown]
# ## Esercizio 4
# Usa Numpy per calcolare una approssimazione dell'integrale definito della funzione f(x) = exp(-x^2) da 0 a 1. Suddividi l'intervallo [0,1] in n sotto-intervalli e per ogni sotto-intervallo approssima l'area sottesa dalla funzione con l'area del corrispondente rettangolo.
# [Suggerimento: usare np.linespace()]
# ![rettangoli](rettangolo.png)
# Calcola il risultato per n=10, 100, 10000, 100000.
