# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## ESERCIZIO COMPITO - COVID

# %% [markdown]
# creare il grafico del file dati_covid.csv, e scegliere 3 categorie da visualizzare. Usare Pandas

# %%
data = pd.read_csv("./dati_covid.csv")

tot_pos = data["totale_positivi"].values
guariti = data["dimessi_guariti"].values
tot_casi = data["totale_casi"].values

# %%
lista_c = [tot_pos, var_tot_pos, tot_casi]
lista_stile = ['r', 'y', 'o']
lista_label = ["totale positivi", "guariti", "totale casi"]

# %%
fig, ax = plt.subplots(figsize = (20, 10))
fig.autofmt_xdate()

ax.set_title("Grafico relazione covid", fontsize = 30, fontweight = 'bold')
ax.grid(True)
    
for a, stili, l in zip(lista_c, lista_stile, lista_label):
    ax.plot(a, stili, label = l)

ax.legend(fontsize = 15)

plt.show()
