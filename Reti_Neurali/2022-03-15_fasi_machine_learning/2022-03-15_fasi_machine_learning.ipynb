# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from joblib import dump, load

# %% [markdown]
# ## 1. Scegliere i dati (importare i dati)

# %%
data = pd.read_csv('./marziani.csv')

print(data.head()) # per farsi un'idea del contenuto
print(">>colonne: ", data.columns) # per vedere le intestazioni di colonna
print(">>tipi\n",data.dtypes) # per vedere i tipi
# Out:
#   specie colore  n_arti  peso  altezza  larghezza
# 0  Robby  viola    20.0  3.87    14.77      73.22
# 1  Robby  viola    27.0  3.15    28.19      88.44
# 2  Robby  viola    25.0  4.35    12.05      76.74
# 3  Robby    blu    20.0  3.76     9.90      81.37
# 4  Robby    blu    28.0  2.86    19.87      84.65
# >>colonne:  Index(['specie', 'colore', 'n_arti', 'peso', 'altezza', 'larghezza'], dtype='object')
# >>tipi
#  specie        object
# colore        object
# n_arti       float64
# peso         float64
# altezza      float64
# larghezza    float64
# dtype: object

# %% [markdown]
# ## 2. Pulizia e preparazione dei dati

# %% [markdown]
# ### Analizzare i dati

# %%
print(">>Specie")
print(data.specie.unique()) # quali sono le specie
print(">>Describe")
print(data['specie'].describe()) # quanti campioni ci sono
# Out:
# >>Specie
# ['Robby' 'Simmy']
# >>Describe
# count      2000
# unique        2
# top       Robby
# freq       1000
# Name: specie, dtype: object

# %%
print(">> Robby\n",data[data['specie'] == 'Robby'].describe())
print(">> Simmy\n",data[data['specie'] == 'Simmy'].describe())
# Out:
# >> Robby
#             n_arti         peso     altezza   larghezza
# count  999.000000  1000.000000  996.000000  999.000000
# mean    24.637638     3.500900   17.518082   84.719429
# std      2.899248     0.489139    4.227621   11.456814
# min     20.000000     2.130000    3.170000   44.700000
# 25%     22.000000     3.170000   14.740000   77.045000
# 50%     25.000000     3.490000   17.330000   84.890000
# 75%     27.000000     3.830000   20.307500   92.510000
# max     29.000000     5.050000   29.400000  117.450000
# >> Simmy
#             n_arti         peso     altezza   larghezza
# count  995.000000  1000.000000  999.000000  998.000000
# mean    24.544724     4.490280   32.769620   70.241653
# std      2.883513     0.518585    5.755694    3.345319
# min     20.000000     2.850000   15.630000   59.440000
# 25%     22.000000     4.147500   29.070000   68.000000
# 50%     25.000000     4.505000   32.640000   70.330000
# 75%     27.000000     4.850000   36.475000   72.610000
# max     29.000000     6.110000   49.750000   80.260000

# %%
for specie in data.specie.unique(): # per ogni specie
    dati = data[data['specie'] == specie]
    print('>>', specie)
    
    for x in data.columns[1:]: # esclusa la colonna specie
        print(dati[x].describe() ) # per avere statistiche sui dati
# Out:
# >> Robby
# count     995
# unique      3
# top       blu
# freq      340
# Name: colore, dtype: object
# count    999.000000
# mean      24.637638
# std        2.899248
# min       20.000000
# 25%       22.000000
# 50%       25.000000
# 75%       27.000000
# max       29.000000
# Name: n_arti, dtype: float64
# count    1000.000000
# mean        3.500900
# std         0.489139
# min         2.130000
# 25%         3.170000
# 50%         3.490000
# 75%         3.830000
# max         5.050000
# Name: peso, dtype: float64
# count    996.000000
# mean      17.518082
# std        4.227621
# min        3.170000
# 25%       14.740000
# 50%       17.330000
# 75%       20.307500
# max       29.400000
# Name: altezza, dtype: float64
# count    999.000000
# mean      84.719429
# std       11.456814
# min       44.700000
# 25%       77.045000
# 50%       84.890000
# 75%       92.510000
# max      117.450000
# Name: larghezza, dtype: float64
# >> Simmy
# count       998
# unique        3
# top       rosso
# freq        339
# Name: colore, dtype: object
# count    995.000000
# mean      24.544724
# std        2.883513
# min       20.000000
# 25%       22.000000
# 50%       25.000000
# 75%       27.000000
# max       29.000000
# Name: n_arti, dtype: float64
# count    1000.000000
# mean        4.490280
# std         0.518585
# min         2.850000
# 25%         4.147500
# 50%         4.505000
# 75%         4.850000
# max         6.110000
# Name: peso, dtype: float64
# count    999.000000
# mean      32.769620
# std        5.755694
# min       15.630000
# 25%       29.070000
# 50%       32.640000
# 75%       36.475000
# max       49.750000
# Name: altezza, dtype: float64
# count    998.000000
# mean      70.241653
# std        3.345319
# min       59.440000
# 25%       68.000000
# 50%       70.330000
# 75%       72.610000
# max       80.260000
# Name: larghezza, dtype: float64

# %% [markdown]
# ### Rendiamo numeriche le label

# %% [markdown]
# Le varibili categoriche devono diventare variabili numeriche, nel nostro caso in 0 1 e 2

# %%
colori = np.sort(data['colore'].dropna().unique()) # colori in ordine alfabetico
print(colori)

d = data.copy() # fa una copia dei dati originali

for k, colore in enumerate(colori): # sostituisce ogni colore con l'indice
    d['colore'].replace(colore, k, inplace = True)

print(d.head())
# Out:
# ['blu' 'rosso' 'viola']
#   specie  colore  n_arti  peso  altezza  larghezza
# 0  Robby     2.0    20.0  3.87    14.77      73.22
# 1  Robby     2.0    27.0  3.15    28.19      88.44
# 2  Robby     2.0    25.0  4.35    12.05      76.74
# 3  Robby     0.0    20.0  3.76     9.90      81.37
# 4  Robby     0.0    28.0  2.86    19.87      84.65

# %%
print(data['colore'].unique()) # senza eliminare i dati mancanti
print(d['colore'].unique()) # associazione del numero al colore
# Out:
# ['viola' 'blu' 'rosso' nan]
# [ 2.  0.  1. nan]

# %% [markdown]
# ### Selezione delle feature

# %%
sns.set_theme(font_scale = 2) # raddoppia la dimensione di tutti i caratteri
sns.pairplot(d, hue = 'specie', dropna = True) #diag_kind="hist"
sns.set() # reimposta i valori di default

# %% [markdown]
# ### Eliminiamo i dati mancanti

# %%
# Colonne con dati mancanti
cols_with_missing = [col for col in d.columns if d[col].isnull().sum()]
print(cols_with_missing)

# caratteristiche scelte per la classificazione
cols_selected = ['peso','altezza', 'larghezza']

# si eliminano le righe con dati mancanti solo nelle colonne selezionate
d = data.dropna(axis = 'index', subset = cols_selected)
print(d.shape)

# Colonne rimanenti con dati mancanti
print([col for col in d.columns if d[col].isnull().sum()])
# Out:
# ['colore', 'n_arti', 'altezza', 'larghezza']
# (1992, 6)
# ['colore', 'n_arti']

# %% [markdown]
# ### X e y

# %%
X = d[cols_selected] #['peso','altezza','larghezza'] --> le features
y = d['specie'] # --> i target
print(X.head())
print(y.head())
# Out:
#    peso  altezza  larghezza
# 0  3.87    14.77      73.22
# 1  3.15    28.19      88.44
# 2  4.35    12.05      76.74
# 3  3.76     9.90      81.37
# 4  2.86    19.87      84.65
# 0    Robby
# 1    Robby
# 2    Robby
# 3    Robby
# 4    Robby
# Name: specie, dtype: object

# %% [markdown]
# ## 3. Suddividere i dati in insieme di training e di test (TRAIN_TEST_SPLIT)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 0) 
# random_state è il seme del generatore, se non inizializzato ogni volta sarà casuale 

print(X_train.head())
print("Numero di campioni in X train: ",X_train.shape[0])
print(y_train.value_counts()) # quanti valori per ogni specie
print(y_train.head())
# Out:
#       peso  altezza  larghezza
# 1853  4.58    29.13      70.59
# 486   3.93    25.37      95.30
# 846   3.95    27.27      73.86
# 376   3.01    21.95      74.95
# 580   3.17    12.02      76.47
# Numero di campioni in X train:  1394
# Simmy    710
# Robby    684
# Name: specie, dtype: int64
# 1853    Simmy
# 486     Robby
# 846     Robby
# 376     Robby
# 580     Robby
# Name: specie, dtype: object

# %% [markdown]
# ### Standarizzazione

# %%
# per visualizzare i dati con solo 3 decimali
pd.options.display.float_format = '{:.3f}'.format

m = X_train.mean()
print(f">>Media: \n{m}")

s = X_train.std()
print(f">>Deviazione standard: \n{s}")

X_train_std = ((X_train - m) / s) # normalizzazione del training set
print(f">>X train Normalizzato \n {X_train_std.describe()}")
# Out:
# >>Media:
# peso         3.995
# altezza     25.276
# larghezza   77.389
# dtype: float64
# >>Deviazione standard:
# peso         0.708
# altezza      9.173
# larghezza   10.984
# dtype: float64
# >>X train Normalizzato
#            peso  altezza  larghezza
# count 1394.000 1394.000   1394.000
# mean    -0.000   -0.000     -0.000
# std      1.000    1.000      1.000
# min     -2.536   -2.410     -2.297
# 25%     -0.742   -0.863     -0.724
# 50%     -0.007   -0.117     -0.360
# 75%      0.755    0.846      0.667
# max      2.988    2.572      3.444

# %%
sns.set_style("white") # imposta lo sfondo bianco senza griglia
fig, axes = plt.subplots(3, 2, figsize = (10, 17), sharey = 'row') # condivide asse y per ogni righe

for i, ax in enumerate(axes):
    col = cols_selected[i] # feature corrente
    
    # etichette dell'asse x e dell'asse y
    ax[0].set_xlabel('dati iniziali', fontsize = 16);
    ax[1].set_xlabel('dati normalizzati', fontsize = 16)
    ax[0].set_ylabel(col + "\nnumero di campioni", fontsize = 20); # asse y condiviso
    
    # grafici della colonna corrente
    sns.histplot(ax = ax[0], x = X_train[col], kde = True)
    sns.histplot(ax = ax[1], x = X_train_std[col], kde = True)
    
sns.set() # reimposta i valori di default

# %%
X_test_std = ((X_test-m)/s) # normalizziamo
print(f">>X test Normalizzato \n {X_test_std.describe()}")

pd.options.display.float_format = None # ripristina la visualizzazione di default
# Out:
# >>X test Normalizzato
#           peso  altezza  larghezza
# count 598.000  598.000    598.000
# mean   -0.001   -0.048      0.026
# std     0.988    0.988      1.035
# min    -2.635   -1.968     -2.976
# 25%    -0.742   -0.876     -0.719
# 50%    -0.014   -0.175     -0.340
# 75%     0.738    0.740      0.701
# max     2.380    2.668      3.647

# %% [markdown]
# ## 4. Scegliere il modello da utilizzare

# %%
model = MLPClassifier(hidden_layer_sizes=(100,100), random_state=1,max_iter=300)

# %% [markdown]
# ## 5. Addestrare il modello FIT

# %%
model.fit(X_train_std, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(100, 100), max_iter=300, random_state=1)

# %%
plt.ylabel('cost')
plt.xlabel('iterations')
plt.title("Learning rate =" + str(model.learning_rate_init))
plt.plot(model.loss_curve_)

plt.show()

# %% [markdown]
# ## 6. Testare il modello PREDICT

# %%
#Predizioni sui dati di training
print("Train")
print(y_train.values[:5])
print(model.predict(X_train_std[:5]))

#Predizioni sui dati di test
print("Test")
print(y_test.values[:5])
print(model.predict(X_test_std[:5]))

#Predizioni su un caso specifico
caso_std = (([4.8,31.4,70.8]-m)/s) #normalizziamo i dati
print("Caso")
print(model.predict([caso_std]))
# Out:
# Train
# ['Simmy' 'Robby' 'Robby' 'Robby' 'Robby']
# ['Simmy' 'Robby' 'Robby' 'Robby' 'Robby']
# Test
# ['Simmy' 'Simmy' 'Robby' 'Robby' 'Simmy']
# ['Simmy' 'Simmy' 'Robby' 'Robby' 'Simmy']
# Caso
# ['Simmy']

# %% [markdown]
# ## 7. Valutare il modello e migliorarlo ACCURANCY_SCORE

# %%
print("Accuratezza dati di TRAIN: %.3f" % model.score(X_train_std, y_train))

# questo è un metodo alternativo per avere l'accuratezza
predictions = model.predict(X_test_std)
# Out:
# Accuratezza dati di TRAIN: 0.984

# %%
score = accuracy_score(y_test, predictions)
print("Accuratezza dati di TEST: %.3f" % score)
# Out:
# Accuratezza dati di TEST: 0.975

# %% [markdown]
# ### Per i regressori

# %%
predictions = model.predict(X_test_std)
mae = mean_absolute_error(predictions, y_test)
print(mae)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   return f(*args, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     652             try:
# --> 653                 array = array.astype(np.float64)
#     654             except ValueError as e:
#
# ValueError: could not convert string to float: 'Simmy'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-54629e3666ce> in <module>
#       1 predictions = model.predict(X_test_std)
# ----> 2 mae = mean_absolute_error(predictions, y_test)
#       3 print(mae)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     180     0.85...
#     181     """
# --> 182     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     183         y_true, y_pred, multioutput)
#     184     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      87     """
#      88     check_consistent_length(y_true, y_pred)
# ---> 89     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      90     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      91
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     653                 array = array.astype(np.float64)
#     654             except ValueError as e:
# --> 655                 raise ValueError(
#     656                     "Unable to convert array of bytes/strings "
#     657                     "into decimal numbers with dtype='numeric'") from e
#
# ValueError: Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'

# %% [markdown]
# ## 7. Ottimizzazione

# %%
start = 100
stop = 300
passo = 10
vEpochs = np.arange(start, stop, passo)
vAccTrain = [] #lista dell'accuratezza sui dati di train
vAccTest = [] #lista dell'accuratezza sui dati di test

for e in vEpochs:
    mlp = MLPClassifier(hidden_layer_sizes=(100,100), random_state=1, max_iter
    mlp.fit(X_train_std, y_train)
    vAccTrain.append(mlp.score(X_train_std, y_train)) # accuratezza sul training sevAccTest.append(mlp.score(X_test_std, y_test)) # accuratezza sul test set

#grafico dell'accuratezza
plt.plot(vEpochs, vAccTrain, c='b', label = 'Train')
plt.plot(vEpochs, vAccTest, c='g', label = 'Test')
plt.legend()
# Out:
#   File "<ipython-input-36-129fa6e5c259>", line 10
#     mlp.fit(X_train_std, y_train)
#     ^
# SyntaxError: invalid syntax

# %%
model01 = MLPClassifier(hidden_layer_sizes=(100,100), random_state=1, max_iter
model01.fit(X_train_std, y_train)
print("Accuratezza dati di TRAIN: %.3f" % model01.score(X_train_std, y_train
print("Accuratezza dati di TEST: %.3f" % model01.score(X_test_std, y_test))
print(model01.predict([caso_std]))
# Out:
#   File "<ipython-input-37-4cd0b9e67da7>", line 2
#     model01.fit(X_train_std, y_train)
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 8. Salviamo il modello

# %%
#per esportare
dump(model01, 'marziani.joblib')

#per importare
modelImportato = load('marziani.joblib')
print(modelImportato.predict([caso_std]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-1f60dc6fee1e> in <module>
#       1 #per esportare
# ----> 2 dump(model01, 'marziani.joblib')
#       3
#       4 #per importare
#       5 modelImportato = load('marziani.joblib')
#
# NameError: name 'model01' is not defined
